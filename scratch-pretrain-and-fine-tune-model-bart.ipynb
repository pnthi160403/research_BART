# %%
# !git clone https://github.com/pnthi1604/vn_spelling_correction_bart_model
# !pip install torchtext

# %%
from vn_spelling_correction_bart_model import train, test, config

# %%
cf = config.get_config(base_dir="/kaggle/working")
cf["tokenizer_dir"] = "/kaggle/input/4-ds-bart-vn-spelling-correction/tokenizer"
cf["train_ds"] = "/kaggle/input/4-ds-bart-vn-spelling-correction/train.csv"
cf["test_ds"] = "/kaggle/input/4-ds-bart-vn-spelling-correction/test.csv"
cf["corpus"] = "/kaggle/input/4-ds-bart-vn-spelling-correction/corpus.csv"
cf["pretrain"] = True
cf["epochs"] = 3

# %%
model = train.train(cf)

# %%
test.test(cf)
